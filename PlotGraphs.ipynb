# %%
import numpy as np
import matplotlib.pyplot as plt

ListColors = []
color_codes = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink',
                        'tab:gray', 'tab:olive', 'tab:cyan', 'gold', 'navy', 'darkorange', 'lime', 'crimson']
line_styles = ['-', '--', '-.', ':']

for l in line_styles:
    for c in color_codes:
        ListColors.append((c, l))  # Storing color code and line style as a tuple

# %% [markdown]
# # Effect of Chaging Pruning Rate

# %% [markdown]
# ## CIFAR10

# %%
#CIFAR10


FileName=["PruningIterations_ResNet18_CIFAR_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR_025PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR_01PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR_005PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_CIFAR_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_CIFAR_025PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_CIFAR_01PR_10Epochs_L2_0005.npz"]

LegendNameNotOOD=["ResNet18: 50%Pr - Non-OOD", "ResNet18: 25%Pr - Non-OOD", "ResNet18: 10%Pr - Non-OOD", "ResNet18: 5%Pr - Non-OOD",
            "VGG16: 50%Pr - Non-OOD", "VGG16: 25%Pr - Non-OOD", "VGG16: 10%Pr - Non-OOD"]

LegendNameOOD=["ResNet18: 50%Pr - OOD", "ResNet18: 25%Pr - OOD", "ResNet18: 10%Pr - OOD", "ResNet18: 5%Pr - OOD",
            "VGG16: 50%Pr - OOD", "VGG16: 25%Pr - OOD", "VGG16: 10%Pr - OOD"]

ColorList=["red", "blue", "green", "orange", "purple", "brown", "black"]

FilePath="Networks/Progress/"



for i in range(len(FileName)):
    NpzPath=FilePath+FileName[i]
    NpzData=np.load(NpzPath,allow_pickle=True)


    PruneRatio=1-NpzData["RemainingWeights_List"]
    TestAcc=NpzData["TestAcc"]
    Avg_Corrup_Acc=NpzData["Avg_Corrup_Acc_List"]

    plt.plot(PruneRatio,TestAcc, color=ColorList[i], label=LegendNameNotOOD[i],marker ='o')
    plt.plot(PruneRatio[Avg_Corrup_Acc!=-1],Avg_Corrup_Acc[Avg_Corrup_Acc!=-1], color=ColorList[i], label=LegendNameOOD[i],marker ='o',linestyle='--')

plt.title("CIFAR10 Accuracy vs Pruning Ratio")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %%
#CIFAR10


FileName=["PruningIterations_ResNet18_CIFAR_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR_025PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR_01PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR_005PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_CIFAR_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_CIFAR_025PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_CIFAR_01PR_10Epochs_L2_0005.npz"]

LegendNameNotOOD=["ResNet18: 50%Pr - Non-OOD", "ResNet18: 25%Pr - Non-OOD", "ResNet18: 10%Pr - Non-OOD", "ResNet18: 5%Pr - Non-OOD",
            "VGG16: 50%Pr - Non-OOD", "VGG16: 25%Pr - Non-OOD", "VGG16: 10%Pr - Non-OOD"]

LegendNameOOD=["ResNet18: 50%Pr - OOD", "ResNet18: 25%Pr - OOD", "ResNet18: 10%Pr - OOD", "ResNet18: 5%Pr - OOD",
            "VGG16: 50%Pr - OOD", "VGG16: 25%Pr - OOD", "VGG16: 10%Pr - OOD"]

ColorList=["red", "blue", "green", "orange", "purple", "brown", "black"]

FilePath="Networks/Progress/"



for i in range(len(FileName)):
    NpzPath=FilePath+FileName[i]
    NpzData=np.load(NpzPath,allow_pickle=True)


    PruneRatio=1-NpzData["RemainingWeights_List"]
    TestAcc=NpzData["TestAcc"]
    Avg_Corrup_Acc=NpzData["Avg_Corrup_Acc_List"]

    plt.plot(PruneRatio[Avg_Corrup_Acc!=-1],Avg_Corrup_Acc[Avg_Corrup_Acc!=-1], color=ColorList[i], label=LegendNameOOD[i],marker ='o',linestyle='--')

plt.title("CIFAR10 Accuracy vs Pruning Ratio")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %%
FileName="PruningIterations_ResNet18_CIFAR_05PR_10Epochs_L2_0005.npz"

FilePath="Networks/Progress/"

NpzPath=FilePath+FileName
NpzData=np.load(NpzPath,allow_pickle=True)
PruneRatio=1-NpzData["RemainingWeights_List"]
TestAcc=NpzData["TestAcc"]
Acc_Corruptions=NpzData["Acc_Corruptions"].item()
CorruptionTypes=list(Acc_Corruptions.keys())

for i in range(len(CorruptionTypes)):

    Acc=np.array(Acc_Corruptions[CorruptionTypes[i]])
    plt.plot(PruneRatio[Acc!=-1], Acc[Acc!=-1], label=CorruptionTypes[i],marker ='o',c=ListColors[i][0],linestyle=ListColors[i][1])


plt.title("CIFAR10 Accuracy vs Pruning Ratio \n ResNet18 for Pr 50%")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

# plt.xlim(0,1)
plt.ylim(40,90)
# Out:
# (40.0, 90.0)

# %%
#CIFAR10


FileName="PruningIterations_ResNet18_CIFAR_005PR_10Epochs_L2_0005.npz"

FilePath="Networks/Progress/"

NpzPath=FilePath+FileName
NpzData=np.load(NpzPath,allow_pickle=True)
PruneRatio=1-NpzData["RemainingWeights_List"]
TestAcc=NpzData["TestAcc"]
Acc_Corruptions=NpzData["Acc_Corruptions"].item()
CorruptionTypes=list(Acc_Corruptions.keys())



for i in range(len(CorruptionTypes)):

    Acc=np.array(Acc_Corruptions[CorruptionTypes[i]])
    plt.plot(PruneRatio[Acc!=-1], Acc[Acc!=-1], label=CorruptionTypes[i],marker ='o',c=ListColors[i][0],linestyle=ListColors[i][1])



plt.title("CIFAR10 Accuracy vs Pruning Ratio \n ResNet18 for Pr 5%")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

# plt.xlim(0,1)
plt.ylim(40,90)
# Out:
# (40.0, 90.0)

# %%
# 10 Epochs vs 50 Epochs

#CIFAR10


FileName=["PruningIterations_ResNet18_CIFAR_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR_05PR_50Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR_025PR_10Epochs_L2_0005.npz"]

LegendNameNotOOD=["ResNet18: 50%Pr/10Epochs - Non-OOD", "ResNet18: 50%Pr/50Epochs - Non-OOD","ResNet18: 50%Pr/10Epochs - Non-OOD","ResNet18: 25%Pr/10Epoch - Non-OOD"]

LegendNameOOD=["ResNet18: 50%Pr/10Epochs - OOD", "ResNet18: 50%Pr/50Epochs - OOD","ResNet18: 25%Pr/10Epochs - OOD"]

ColorList=["red", "blue", "green", "orange", "purple", "brown", "black"]

FilePath="Networks/Progress/"



for i in range(len(FileName)):
    NpzPath=FilePath+FileName[i]
    NpzData=np.load(NpzPath,allow_pickle=True)


    PruneRatio=1-NpzData["RemainingWeights_List"]
    TestAcc=NpzData["TestAcc"]
    Avg_Corrup_Acc=NpzData["Avg_Corrup_Acc_List"]

    plt.plot(PruneRatio,TestAcc, color=ColorList[i], label=LegendNameNotOOD[i],marker ='o')
    plt.plot(PruneRatio[Avg_Corrup_Acc!=-1],Avg_Corrup_Acc[Avg_Corrup_Acc!=-1], color=ColorList[i], label=LegendNameOOD[i],marker ='o',linestyle='--')

plt.title("CIFAR10 Accuracy vs Pruning Ratio")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## IMAGENET

# %%
FileName=["PruningIterations_ResNet18_IMAGENET_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_IMAGENET_025PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_IMAGENET_01PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_IMAGENET_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_IMAGENET_025PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_IMAGENET_01PR_10Epochs_L2_0005.npz"]

LegendNameNotOOD=["ResNet18: 50%Pr - Non-OOD", "ResNet18: 25%Pr - Non-OOD", "ResNet18: 10%Pr - Non-OOD",
            "VGG16: 50%Pr - Non-OOD", "VGG16: 25%Pr - Non-OOD", "VGG16: 10%Pr - Non-OOD"]

LegendNameOOD=["ResNet18: 50%Pr - OOD", "ResNet18: 25%Pr - OOD", "ResNet18: 10%Pr - OOD",
            "VGG16: 50%Pr - OOD", "VGG16: 25%Pr - OOD", "VGG16: 10%Pr - OOD"]

ColorList=["red", "blue", "green", "orange", "purple", "brown", "black"]

FilePath="Networks/Progress/"


for i in range(len(FileName)):
    NpzPath=FilePath+FileName[i]
    NpzData=np.load(NpzPath,allow_pickle=True)


    PruneRatio=1-NpzData["RemainingWeights_List"]
    TestAcc=NpzData["TestAcc"]
    Avg_Corrup_Acc=NpzData["Avg_Corrup_Acc_List"]

    plt.plot(PruneRatio,TestAcc, color=ColorList[i], label=LegendNameNotOOD[i],marker ='o')
    plt.plot(PruneRatio[Avg_Corrup_Acc!=-1],Avg_Corrup_Acc[Avg_Corrup_Acc!=-1], color=ColorList[i], label=LegendNameOOD[i],marker ='o',linestyle='--')

plt.title("TINY-IMAGENET Accuracy vs Pruning Ratio")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %%
FileName=["PruningIterations_ResNet18_IMAGENET_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_IMAGENET_025PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_IMAGENET_01PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_IMAGENET_05PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_IMAGENET_025PR_10Epochs_L2_0005.npz",
          "PruningIterations_VGG16_IMAGENET_01PR_10Epochs_L2_0005.npz"]

LegendNameNotOOD=["ResNet18: 50%Pr - Non-OOD", "ResNet18: 25%Pr - Non-OOD", "ResNet18: 10%Pr - Non-OOD",
            "VGG16: 50%Pr - Non-OOD", "VGG16: 25%Pr - Non-OOD", "VGG16: 10%Pr - Non-OOD"]

LegendNameOOD=["ResNet18: 50%Pr - OOD", "ResNet18: 25%Pr - OOD", "ResNet18: 10%Pr - OOD",
            "VGG16: 50%Pr - OOD", "VGG16: 25%Pr - OOD", "VGG16: 10%Pr - OOD"]

ColorList=["red", "blue", "green", "orange", "purple", "brown", "black"]

FilePath="Networks/Progress/"


for i in range(len(FileName)):
    NpzPath=FilePath+FileName[i]
    NpzData=np.load(NpzPath,allow_pickle=True)


    PruneRatio=1-NpzData["RemainingWeights_List"]
    TestAcc=NpzData["TestAcc"]
    Avg_Corrup_Acc=NpzData["Avg_Corrup_Acc_List"]

    plt.plot(PruneRatio,TestAcc, color=ColorList[i], label=LegendNameNotOOD[i],marker ='o')
    plt.plot(PruneRatio[Avg_Corrup_Acc!=-1],Avg_Corrup_Acc[Avg_Corrup_Acc!=-1], color=ColorList[i], label=LegendNameOOD[i],marker ='o',linestyle='--')

plt.title("TINY-IMAGENET Accuracy vs Pruning Ratio")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

plt.xlim(0.7,1)
# Out:
# (0.7, 1.0)

# %%
FileName="PruningIterations_ResNet18_IMAGENET_01PR_10Epochs_L2_0005.npz"

FilePath="Networks/Progress/"

NpzPath=FilePath+FileName
NpzData=np.load(NpzPath,allow_pickle=True)
PruneRatio=1-NpzData["RemainingWeights_List"]
TestAcc=NpzData["TestAcc"]
Acc_Corruptions=NpzData["Acc_Corruptions"].item()
CorruptionTypes=list(Acc_Corruptions.keys())



for i in range(len(CorruptionTypes)):

    Acc=np.array(Acc_Corruptions[CorruptionTypes[i]])
    plt.plot(PruneRatio[Acc!=-1], Acc[Acc!=-1], label=CorruptionTypes[i],marker ='o',c=ListColors[i][0],linestyle=ListColors[i][1])



plt.title("TINY-IMAGENET Accuracy vs Pruning Ratio \n ResNet18 for Pr 10%")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

# plt.xlim(0,1)
#plt.ylim(40,90)

# %% [markdown]
# # Adversarial Example

# %% [markdown]
# ## CIFAR10

# %%
FileName=["PruningIterations_ResNet18_CIFAR_01PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR10_V0_Adversarial_ep_05p_01PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR10_V0_Adversarial_ep_1p_01PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_CIFAR10_V0_Adversarial_ep_3p_01PR_10Epochs_L2_0005.npz"]

LegendNameNotOOD=["$\epsilon$=0% (Non-OOD)", "$\epsilon$=0.5% (Non-OOD)", "$\epsilon$=1% (Non-OOD)","$\epsilon$=3% (Non-OOD)"]

LegendNameOOD=["$\epsilon$=0% (OOD)", "$\epsilon$=0.5% (OOD)", "$\epsilon$=1% (OOD)","$\epsilon$=3% (OOD)"]

ColorList=["red", "blue", "green", "orange", "purple", "brown", "black"]

FilePath="Networks/Progress/"


for i in range(len(FileName)):
    NpzPath=FilePath+FileName[i]
    NpzData=np.load(NpzPath,allow_pickle=True)


    PruneRatio=1-NpzData["RemainingWeights_List"]
    TestAcc=NpzData["TestAcc"]
    Avg_Corrup_Acc=NpzData["Avg_Corrup_Acc_List"]

    plt.plot(PruneRatio,TestAcc, color=ColorList[i], label=LegendNameNotOOD[i],marker ='o')
    plt.plot(PruneRatio[Avg_Corrup_Acc!=-1],Avg_Corrup_Acc[Avg_Corrup_Acc!=-1], color=ColorList[i], label=LegendNameOOD[i],marker ='o',linestyle='--')

plt.title("ResNet18 on CIFAR10 Accuracy vs Pruning Ratio")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

plt.xlim(0.7,1)
# Out:
# (0.7, 1.0)

# %%
FileName="PruningIterations_ResNet18_CIFAR_01PR_10Epochs_L2_0005.npz"
FilePath="Networks/Progress/"

NpzPath=FilePath+FileName
NpzData=np.load(NpzPath,allow_pickle=True)
PruneRatio=1-NpzData["RemainingWeights_List"]
TestAcc=NpzData["TestAcc"]
Acc_Corruptions=NpzData["Acc_Corruptions"].item()
CorruptionTypes1=list(Acc_Corruptions.keys())

FileName1="PruningIterations_ResNet18_CIFAR10_V0_Adversarial_ep_05p_01PR_10Epochs_L2_0005.npz"
FilePath="Networks/Progress/"

NpzPath1=FilePath+FileName1
NpzData1=np.load(NpzPath1,allow_pickle=True)
PruneRatio1=1-NpzData1["RemainingWeights_List"]
TestAcc1=NpzData1["TestAcc"]
Acc_Corruptions1=NpzData1["Acc_Corruptions"].item()
CorruptionTypes2=list(Acc_Corruptions.keys())

for i in range(len(CorruptionTypes)):

    Acc1=np.array(Acc_Corruptions[CorruptionTypes[i]])
    Acc2=np.array(Acc_Corruptions1[CorruptionTypes[i]])
    Acc=Acc1-Acc2
    IdxIn=(Acc1!=-1)* (Acc2!=-1)
    plt.plot(PruneRatio[IdxIn], Acc[IdxIn], label=CorruptionTypes[i],marker ='o',c=ListColors[i][0],linestyle=ListColors[i][1])



plt.title("CIFAR10 Accuracy vs Pruning Ratio \n ResNet18 for Pr 10%- $\epsilon$=0.5%")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy (No Augmentation - With Augmentation)\n Negative values indicate improvement")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

# plt.xlim(0.7,1)
#plt.ylim(40,90)

# %% [markdown]
# ## TINY-IMAGENET

# %%
FileName=["PruningIterations_ResNet18_IMAGENET_01PR_10Epochs_L2_0005.npz",
          "PruningIterations_ResNet18_TiniyImageNet_V0_Adversarial_ep_05p_01PR_10Epochs_L2_0005.npz"]

LegendNameNotOOD=["$\epsilon$=0% (Non-OOD)", "$\epsilon$=0.5% (Non-OOD)", "$\epsilon$=1% (Non-OOD)","$\epsilon$=3% (Non-OOD)"]

LegendNameOOD=["$\epsilon$=0% (OOD)", "$\epsilon$=0.5% (OOD)", "$\epsilon$=1% (OOD)","$\epsilon$=3% (OOD)"]

ColorList=["red", "blue", "green", "orange", "purple", "brown", "black"]

FilePath="Networks/Progress/"


for i in range(len(FileName)):
    NpzPath=FilePath+FileName[i]
    NpzData=np.load(NpzPath,allow_pickle=True)


    PruneRatio=1-NpzData["RemainingWeights_List"]
    TestAcc=NpzData["TestAcc"]
    Avg_Corrup_Acc=NpzData["Avg_Corrup_Acc_List"]

    plt.plot(PruneRatio,TestAcc, color=ColorList[i], label=LegendNameNotOOD[i],marker ='o')
    plt.plot(PruneRatio[Avg_Corrup_Acc!=-1],Avg_Corrup_Acc[Avg_Corrup_Acc!=-1], color=ColorList[i], label=LegendNameOOD[i],marker ='o',linestyle='--')

plt.title("ResNet18 on Tiny ImageNEt Accuracy vs Pruning Ratio")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

plt.xlim(0.7,1)
# Out:
# (0.7, 1.0)

# %%
FileName="PruningIterations_ResNet18_IMAGENET_01PR_10Epochs_L2_0005.npz"
FilePath="Networks/Progress/"

NpzPath=FilePath+FileName
NpzData=np.load(NpzPath,allow_pickle=True)
PruneRatio=1-NpzData["RemainingWeights_List"]
TestAcc=NpzData["TestAcc"]
Acc_Corruptions=NpzData["Acc_Corruptions"].item()
CorruptionTypes1=list(Acc_Corruptions.keys())

FileName1="PruningIterations_ResNet18_TiniyImageNet_V0_Adversarial_ep_05p_01PR_10Epochs_L2_0005.npz"
FilePath="Networks/Progress/"

NpzPath1=FilePath+FileName1
NpzData1=np.load(NpzPath1,allow_pickle=True)
PruneRatio1=1-NpzData1["RemainingWeights_List"]
TestAcc1=NpzData1["TestAcc"]
Acc_Corruptions1=NpzData1["Acc_Corruptions"].item()
CorruptionTypes2=list(Acc_Corruptions.keys())

for i in range(len(CorruptionTypes)):

    Acc1=np.array(Acc_Corruptions[CorruptionTypes[i]])
    Acc2=np.array(Acc_Corruptions1[CorruptionTypes[i]])
    Acc=Acc1-Acc2
    IdxIn=(Acc1!=-1)* (Acc2!=-1)
    plt.plot(PruneRatio[IdxIn], Acc[IdxIn], label=CorruptionTypes[i],marker ='o',c=ListColors[i][0],linestyle=ListColors[i][1])


plt.title("Tiny ImageNet Accuracy vs Pruning Ratio \n ResNet18 for Pr 10%- $\epsilon$=0.5%")
plt.xlabel("Pruning Ratio")
plt.ylabel("Accuracy (No Augmentation - With Augmentation)\n Negative values indicate improvement")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., frameon=False)

# plt.xlim(0.7,1)
#plt.ylim(40,90)
